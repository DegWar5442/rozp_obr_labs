# %%
################################################
### using filtered data

# %%
import pickle
with open('shaped.pickle', 'rb') as f:
    ab = pickle.load(f)

# %%
ab.shape
# Out:
# (297, 1200)

# %%
from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics, svm
#from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn import decomposition, ensemble

import numpy #,  string #pandas, xgboost, textblob,
#from tensorflow.keras.preprocessing import text, sequence
from tensorflow.keras import layers, models, optimizers

# %%
import tensorflow as tf
tf. __version__
# Out:
# '2.19.0'

# %%
# Define models:

def train_model(classifier, feature_vector_train, label, feature_vector_valid, is_neural_net=False):
    # fit the training dataset on the classifier
    classifier.fit(feature_vector_train, label)

    # predict the labels on validation dataset
    predictions = classifier.predict(feature_vector_valid)

    if is_neural_net:
        predictions = predictions.argmax(axis=-1)

    return metrics.accuracy_score(predictions, valid_y)

def train_model2(classifier, feature_vector_train, label, feature_vector_valid, valid_Y, is_neural_net=False):
    # fit the training dataset on the classifier
    classifier.fit(feature_vector_train, label)

    # predict the labels on validation dataset
    predictions = classifier.predict(feature_vector_valid)

    if is_neural_net:
        predictions = predictions.argmax(axis=-1)

    return metrics.accuracy_score(predictions, valid_Y)

# %%
from sklearn.decomposition import PCA
from sklearn.decomposition import TruncatedSVD
import numpy as np
from scipy.sparse import csr_matrix

from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
import time
import warnings

import matplotlib.pyplot as plt

from sklearn import cluster, datasets, mixture
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler
from itertools import cycle, islice

import scipy

# %%
y_ = np.ones(len(ab))

# %%
start_time = time.time()
#a = np.reshape(np.array(tempvar),(297*20,60))

#base parameters
default_base = {'quantile': .3,
                'eps': .3,
                'damping': .9,
                'preference': -200,
                'n_neighbors': 10, #maybe more
                'n_clusters': 4, #3 is actual number
                'min_samples': 20,
                'xi': 0.05,
                'min_cluster_size': 0.1}

params = default_base.copy()

pca = TruncatedSVD(n_components=10)
pca.fit(ab)
#csr_matrix(
transformed_ = pca.transform(ab)
end_time = time.time()
end_time-start_time
# Out:
# 0.07709240913391113

# %%
#X_embedded2 = X_embedded

# %%
#X_embedded = transformed_

# %%
start_time = time.time()
#X_embedded = TSNE(n_components=2).fit_transform(transformed_)
X_embedded = transformed_
end_time = time.time()
end_time-start_time
# Out:
# 7.343292236328125e-05

# %%
# ============
# Create cluster objects
# ============



two_means = cluster.MiniBatchKMeans(n_clusters=params['n_clusters'])

clustering_algorithms = (
        ('MBatchKMeans', two_means),
)

plot_num = 1

# %%
for name, algorithm in clustering_algorithms:

        t0 = time.time()

        # catch warnings related to kneighbors_graph
        with warnings.catch_warnings():
            warnings.filterwarnings(
                "ignore",
                message="the number of connected components of the " +
                "connectivity matrix is [0-9]{1,2}" +
                " > 1. Completing it to avoid stopping the tree early.",
                category=UserWarning)
            warnings.filterwarnings(
                "ignore",
                message="Graph is not fully connected, spectral embedding" +
                " may not work as expected.",
                category=UserWarning)
            algorithm.fit(X_embedded)



        t1 = time.time()

        if hasattr(algorithm, 'labels_'):
            y_pred = algorithm.labels_.astype(int)
        else:
            y_pred = algorithm.predict(X_embedded)

        plt.subplot(1, len(clustering_algorithms), plot_num)

        colors = np.array(list(islice(cycle(['#377eb8', '#ff7f00', '#4daf4a',
                                             '#f781bf', '#a65628', '#984ea3',
                                             '#999999', '#e41a1c', '#dede00']),
                                      int(max(y_pred) + 1))))
        # add black color for outliers (if any)
        colors = np.append(colors, ["#000000"])


        plt.scatter(X_embedded[:, 0], X_embedded[:, 1], s=2, color=colors[y_pred])

        plt.xlim(-2.5, 2.5)
        plt.ylim(-2.5, 2.5)
        plt.xticks(())
        plt.yticks(())

        plot_num += 1

        # stop, plot only one image
        break

#plt.show()
t1-t0
# Out:
# 0.10069990158081055

# %%
colors = np.array(list(islice(cycle(['#377eb8', '#ff7f00', '#4daf4a',
                                             '#f781bf', '#a65628', '#984ea3',
                                             '#999999', '#e41a1c', '#dede00']), int(max(y_pred) + 1))))

plt.figure(figsize=(6, 6))
plt.scatter(X_embedded[:, 0], X_embedded[:, 1], s=2, c=colors[y_pred])
plt.colorbar()
plt.show()

# %%
y_pred.shape
# Out:
# (297,)

# %%
#optional classifiers to choose
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
#import seaborn as sns

# %%
# ab (297x1200)!

# %%
start_time = time.time()
train_x, valid_x, train_y, valid_y = model_selection.train_test_split(X_embedded, y_pred)
end_time = time.time()
end_time-start_time
# Out:
# 0.004651546478271484

# %%
import numpy as np
#import pandas as pd
import os

import tensorflow as tf
#import tensorflow_addons as tfa #none
from tensorflow.keras import layers

import matplotlib.pyplot as plt
from IPython import display
from IPython.display import clear_output

import glob
#import imageio
import time
import IPython.display as ipd

#AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
# Shallow Neural Networks
# model nx100xn

import numpy as np
import scipy.sparse
import tensorflow as tf

import tensorflow.keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers

# %%
import tensorflow.keras as keras
from tensorflow.keras import backend as K

# %%
from tensorflow.keras.layers import Input, Dense, Flatten, Reshape
from tensorflow.keras.models import Model

# %%
def create_dense_ae():
    # Розмірність кодованого простору
    hidden_dim = 60
    encoding_dim = 2

    # Кодувальник
    input = Input(shape=(10*1, )) # 10*1,  - розмірність вхідного шару
    # Додатковий шар для кодування вхідного представлення
    flat = Flatten()(input)

    hidden = Dense(hidden_dim, activation='relu')(flat)
    hidden2 = Dense(hidden_dim, activation='relu')(hidden)
    # Приховане подання кодувальника
    encoded = Dense(encoding_dim, activation='relu')(hidden2)

    # Декодувальник
    # Аналогічним чином, але послідовність шарів протилежна кодувальнику
    input_encoded = Input(shape=(encoding_dim,))
    hidden_encoded = Dense(hidden_dim, activation='sigmoid')(input_encoded)
    hidden_encoded2 = Dense(hidden_dim, activation='sigmoid')(hidden_encoded)

    flat_decoded = Dense(10*1, activation='sigmoid')(hidden_encoded2)
    decoded = Reshape((10*1, ))(flat_decoded)

    # Таким чином можна подати окремо модель як для кодувальника так і декодувальника
    # Або подавати шари окермо
    encoder = Model(input, encoded, name="encoder")
    decoder = Model(input_encoded, decoded, name="decoder")
    autoencoder = Model(input, decoder(encoder(input)), name="autoencoder")
    return encoder, decoder, autoencoder

# %%
# перелік наявних пристроїв (Ubuntu)

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
with tf.device("/device:GPU:0"):
    encoder, decoder, autoencoder = create_dense_ae()
    autoencoder.compile(optimizer='adam', loss='binary_crossentropy', metrics=["accuracy"])

# %%
# якщо все гаразд, у консолі Conda має бути подібний текст:
# tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with XXXX MB memory:  -> device: 0, name: __YOUR GPU___, pci bus id: 0000:08:00.0, compute capability: Y.W

# %%
# якщо немає відеокарти як такої (наприклад, якщо є процесор з ARM архітектурою без виділеного відеоядра), можливо написати і так:

# %%
#with tf.device("/device:CPU:0"):
#    encoder, decoder, autoencoder = create_dense_ae()
#    autoencoder.compile(optimizer='adam', loss='binary_crossentropy', metrics=["accuracy"])

# %%
import tensorflow as tf
tf.get_logger().setLevel('INFO')

# %%
autoencoder.summary()
# Out:
# Model: "autoencoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 10)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoder (Functional)            │ (None, 2)              │         4,442 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder (Functional)            │ (None, 10)             │         4,450 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,892 (34.73 KB)
#  Trainable params: 8,892 (34.73 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
with tf.device("/device:GPU:0"):
    start_time = time.time()
    autoencoder.fit(train_x, train_x,
        epochs=500,
        batch_size=50,
        shuffle=True,
        validation_data=(valid_x, valid_x))
    end_time = time.time()
    #end_time-start_time
# Out:
# Epoch 1/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 508ms/step - accuracy: 0.0946 - loss: 0.4464 - val_accuracy: 0.0667 - val_loss: 0.2651
# Epoch 2/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0946 - loss: 0.2280 - val_accuracy: 0.0667 - val_loss: 0.0459
# Epoch 3/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0946 - loss: 0.0237 - val_accuracy: 0.0667 - val_loss: -0.1691
# Epoch 4/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0946 - loss: -0.1698 - val_accuracy: 0.1467 - val_loss: -0.3854
# Epoch 5/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4550 - loss: -0.3686 - val_accuracy: 0.5467 - val_loss: -0.6025
# Epoch 6/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4595 - loss: -0.5655 - val_accuracy: 0.5467 - val_loss: -0.8205
# Epoch 7/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4595 - loss: -0.7730 - val_accuracy: 0.5467 - val_loss: -1.0420
# Epoch 8/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4595 - loss: -0.9789 - val_accuracy: 0.5467 - val_loss: -1.2716
# Epoch 9/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4595 - loss: -1.1973 - val_accuracy: 0.5467 - val_loss: -1.5053
# Epoch 10/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.4595 - loss: -1.4157 - val_accuracy: 0.5467 - val_loss: -1.7430
# Epoch 11/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5766 - loss: -1.6347 - val_accuracy: 0.7200 - val_loss: -1.9803
# Epoch 12/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6532 - loss: -1.8575 - val_accuracy: 0.7200 - val_loss: -2.2167
# Epoch 13/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6532 - loss: -2.0781 - val_accuracy: 0.7200 - val_loss: -2.4540
# Epoch 14/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6532 - loss: -2.3025 - val_accuracy: 0.7200 - val_loss: -2.6973
# Epoch 15/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6532 - loss: -2.5267 - val_accuracy: 0.7200 - val_loss: -2.9424
# Epoch 16/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6532 - loss: -2.7572 - val_accuracy: 0.7200 - val_loss: -3.1934
# Epoch 17/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6532 - loss: -2.9896 - val_accuracy: 0.7200 - val_loss: -3.4441
# Epoch 18/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6532 - loss: -3.2222 - val_accuracy: 0.7200 - val_loss: -3.6973
# Epoch 19/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6532 - loss: -3.4593 - val_accuracy: 0.7200 - val_loss: -3.9491
# Epoch 20/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6532 - loss: -3.6939 - val_accuracy: 0.7200 - val_loss: -4.2080
# Epoch 21/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6532 - loss: -3.9344 - val_accuracy: 0.7200 - val_loss: -4.4644
# Epoch 22/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6532 - loss: -4.1761 - val_accuracy: 0.7200 - val_loss: -4.7165
# Epoch 23/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6532 - loss: -4.4139 - val_accuracy: 0.7200 - val_loss: -4.9694
# Epoch 24/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6532 - loss: -4.6526 - val_accuracy: 0.7200 - val_loss: -5.2187
# Epoch 25/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6532 - loss: -4.8886 - val_accuracy: 0.7200 - val_loss: -5.4663
# Epoch 26/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6532 - loss: -5.1191 - val_accuracy: 0.7200 - val_loss: -5.7101
# Epoch 27/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.
500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6486 - loss: -15.0644 - val_accuracy: 0.7067 - val_loss: -14.3799
# Epoch 260/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6486 - loss: -15.0710 - val_accuracy: 0.7067 - val_loss: -14.3843
# Epoch 261/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6486 - loss: -15.0782 - val_accuracy: 0.7067 - val_loss: -14.3867
# Epoch 262/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6486 - loss: -15.0827 - val_accuracy: 0.7067 - val_loss: -14.3920
# Epoch 263/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6486 - loss: -15.0881 - val_accuracy: 0.7067 - val_loss: -14.3936
# Epoch 264/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6396 - loss: -15.0929 - val_accuracy: 0.7067 - val_loss: -14.3983
# Epoch 265/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5541 - loss: -15.0988 - val_accuracy: 0.7067 - val_loss: -14.4015
# Epoch 266/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6486 - loss: -15.1030 - val_accuracy: 0.7200 - val_loss: -14.4065
# Epoch 267/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6532 - loss: -15.1072 - val_accuracy: 0.7200 - val_loss: -14.4079
# Epoch 268/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6532 - loss: -15.1122 - val_accuracy: 0.7200 - val_loss: -14.4131
# Epoch 269/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6532 - loss: -15.1185 - val_accuracy: 0.7200 - val_loss: -14.4157
# Epoch 270/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6532 - loss: -15.1232 - val_accuracy: 0.7200 - val_loss: -14.4191
# Epoch 271/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6532 - loss: -15.1292 - val_accuracy: 0.7067 - val_loss: -14.4249
# Epoch 272/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6486 - loss: -15.1341 - val_accuracy: 0.7067 - val_loss: -14.4279
# Epoch 273/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6486 - loss: -15.1396 - val_accuracy: 0.7067 - val_loss: -14.4318
# Epoch 274/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6441 - loss: -15.1446 - val_accuracy: 0.7067 - val_loss: -14.4356
# Epoch 275/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5225 - loss: -15.1495 - val_accuracy: 0.7067 - val_loss: -14.4414
# Epoch 276/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6486 - loss: -15.1542 - val_accuracy: 0.7200 - val_loss: -14.4487
# Epoch 277/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6532 - loss: -15.1598 - val_accuracy: 0.7200 - val_loss: -14.4529
# Epoch 278/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6532 - loss: -15.1642 - val_accuracy: 0.7200 - val_loss: -14.4574
# Epoch 279/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6532 - loss: -15.1701 - val_accuracy: 0.7200 - val_loss: -14.4636
# Epoch 280/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6532 - loss: -15.1754 - val_accuracy: 0.7200 - val_loss: -14.4648
# Epoch 281/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6532 - loss: -15.1803 - val_accuracy: 0.7200 - val_loss: -14.4700
# Epoch 282/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6532 - loss: -15.1851 - val_accuracy: 0.7067 - val_loss: -14.4768
# Epoch 283/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6486 - loss: -15.1902 - val_accuracy: 0.7067 - val_loss: -14.4826
# Epoch 284/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6486 - loss: -15.1960 - val_accuracy: 0.7067 - val_loss: -14.4869
# Epoch 285/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6396 - loss: -15.2020 - val_accuracy: 0.7067 - val_loss: -14.4913
# Epoch 286/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5360 - loss: -15.2073 - val_accuracy: 0.7067 - val_loss: -14.4962
# Epoch 287/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6532 - loss: -15.2141 - val_accuracy: 0.7200 - val_loss: -14.5005
# Epoch 288/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6532 - loss: -15.2215 - val_accuracy: 0.7200 - val_loss: -14.5027
# Epoch 289/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6532 - loss: -15.2262 - val_accuracy: 0.7200 - val_loss: -14.5038
# Epoch 290/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6532 - loss: -15.2318 - val_accuracy: 0.7200 - val_loss: -14.5070
# Epoch 291/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6532 - loss: -15.2371 - val_accuracy: 0.7200 - val_loss: -14.5106
# Epoch 292/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6532 - loss: -15.2426 - val_accuracy: 0.7200 - val_loss: -14.5178
# Epoch 293/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6532 - loss: -15
500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6982 - loss: -16.0706 - val_accuracy: 0.7067 - val_loss: -15.0909
# Epoch 471/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6982 - loss: -16.0745 - val_accuracy: 0.7067 - val_loss: -15.0925
# Epoch 472/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7027 - loss: -16.0795 - val_accuracy: 0.7067 - val_loss: -15.0939
# Epoch 473/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6982 - loss: -16.0841 - val_accuracy: 0.7467 - val_loss: -15.0967
# Epoch 474/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6982 - loss: -16.0884 - val_accuracy: 0.7467 - val_loss: -15.0993
# Epoch 475/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6982 - loss: -16.0911 - val_accuracy: 0.7467 - val_loss: -15.1013
# Epoch 476/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6982 - loss: -16.0954 - val_accuracy: 0.7067 - val_loss: -15.1010
# Epoch 477/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7027 - loss: -16.0979 - val_accuracy: 0.7067 - val_loss: -15.1022
# Epoch 478/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7027 - loss: -16.1030 - val_accuracy: 0.7467 - val_loss: -15.1020
# Epoch 479/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6982 - loss: -16.1069 - val_accuracy: 0.7467 - val_loss: -15.1043
# Epoch 480/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6982 - loss: -16.1082 - val_accuracy: 0.7467 - val_loss: -15.1057
# Epoch 481/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7027 - loss: -16.1129 - val_accuracy: 0.7067 - val_loss: -15.1141
# Epoch 482/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7027 - loss: -16.1171 - val_accuracy: 0.7067 - val_loss: -15.1157
# Epoch 483/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7027 - loss: -16.1219 - val_accuracy: 0.7467 - val_loss: -15.1188
# Epoch 484/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6982 - loss: -16.1267 - val_accuracy: 0.7467 - val_loss: -15.1201
# Epoch 485/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6982 - loss: -16.1301 - val_accuracy: 0.7467 - val_loss: -15.1226
# Epoch 486/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7027 - loss: -16.1342 - val_accuracy: 0.7067 - val_loss: -15.1278
# Epoch 487/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7027 - loss: -16.1379 - val_accuracy: 0.7067 - val_loss: -15.1311
# Epoch 488/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7027 - loss: -16.1425 - val_accuracy: 0.7467 - val_loss: -15.1337
# Epoch 489/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6982 - loss: -16.1458 - val_accuracy: 0.6933 - val_loss: -15.1360
# Epoch 490/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6892 - loss: -16.1507 - val_accuracy: 0.7467 - val_loss: -15.1373
# Epoch 491/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6982 - loss: -16.1539 - val_accuracy: 0.7467 - val_loss: -15.1372
# Epoch 492/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6982 - loss: -16.1565 - val_accuracy: 0.7467 - val_loss: -15.1419
# Epoch 493/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6982 - loss: -16.1615 - val_accuracy: 0.7467 - val_loss: -15.1414
# Epoch 494/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6982 - loss: -16.1659 - val_accuracy: 0.7467 - val_loss: -15.1438
# Epoch 495/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6982 - loss: -16.1699 - val_accuracy: 0.7467 - val_loss: -15.1441
# Epoch 496/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6982 - loss: -16.1749 - val_accuracy: 0.7067 - val_loss: -15.1473
# Epoch 497/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6892 - loss: -16.1784 - val_accuracy: 0.7067 - val_loss: -15.1483
# Epoch 498/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7027 - loss: -16.1826 - val_accuracy: 0.7467 - val_loss: -15.1510
# Epoch 499/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6982 - loss: -16.1860 - val_accuracy: 0.7467 - val_loss: -15.1534
# Epoch 500/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6982 - loss: -16.1904 - val_accuracy: 0.7467 - val_loss: -15.1570

# %%
# зауважте, що час виконання залежно від версії або типу обладнання може суттєво відрізнятися
# час виконання на першій ітерації під відеокартою зазвичай вищий, ніж на наступних

# %%
#Because latent space is two-dimensional, there are a few visualizations that can be done at this point.
#One is to look at the neighborhoods of different classes on the latent 2D plane:
colors = np.array(list(islice(cycle(['#377eb8', '#ff7f00', '#4daf4a',
                                             '#f781bf', '#a65628', '#984ea3',
                                             '#999999', '#e41a1c', '#dede00']), int(max(valid_y) + 1))))

start_time = time.time()
x_train_encoded = encoder.predict(train_x, batch_size=500)
plt.figure(figsize=(6, 6))
plt.scatter(x_train_encoded[:, 0], x_train_encoded[:, 1], c = colors[train_y])
plt.colorbar()
plt.show()

x_test_encoded = encoder.predict(valid_x, batch_size=500)
plt.figure(figsize=(6, 6))
plt.scatter(x_test_encoded[:, 0], x_test_encoded[:, 1], c = colors[valid_y])
plt.colorbar()
plt.show()
end_time = time.time()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step

# %%
start_time = time.time()
train_x, valid_x, train_y, valid_y = model_selection.train_test_split(ab, y_pred)
end_time = time.time()
end_time-start_time
# Out:
# 0.0032835006713867188

# %%
from sklearn.datasets import make_classification
from imblearn.over_sampling import RandomOverSampler
start_time = time.time()
ros = RandomOverSampler(random_state=0)
X_resampled, y_resampled = ros.fit_resample(X_embedded, y_pred)
end_time = time.time()
end_time-start_time
# Out:
# 0.0018665790557861328

# %%
colors = np.array(list(islice(cycle(['#377eb8', '#ff7f00', '#4daf4a',
                                             '#f781bf', '#a65628', '#984ea3',
                                             '#999999', '#e41a1c', '#dede00']), int(max(y_pred) + 1))))

plt.figure(figsize=(6, 6))
plt.scatter(X_embedded[:, 0], X_embedded[:, 1], s=2, c=colors[y_pred])
plt.colorbar()
plt.show()

plt.figure(figsize=(6, 6))
plt.scatter(X_resampled[:, 0], X_resampled[:, 1], s=2, c=colors[y_resampled])
plt.colorbar()
plt.show()

# %%
train_x, valid_x, train_y, valid_y = model_selection.train_test_split(X_resampled, y_resampled)

# %%
#X_resampled, y_resampled = ros.fit_resample(X_embedded, y_pred)

# %%
from imblearn.over_sampling import SMOTE, ADASYN
start_time = time.time()
X_resampled2, y_resampled2 = SMOTE().fit_resample(X_embedded, y_pred)
#print(sorted(Counter(y_resampled).items()))
end_time = time.time()
end_time-start_time
# Out:
# 0.008124828338623047

# %%
start_time = time.time()
clf_smote = LinearSVC().fit(X_resampled2, y_resampled2)
end_time = time.time()
end_time-start_time
# Out:
# 0.008596658706665039

# %%
start_time = time.time()
X_resampled3, y_resampled3 = ADASYN().fit_resample(X_embedded, y_pred)
#print(sorted(Counter(y_resampled).items()))
end_time = time.time()
end_time-start_time
# Out:
# 0.009470224380493164

# %%
start_time = time.time()
clf_adasyn = LinearSVC().fit(X_resampled3, y_resampled3)
end_time = time.time()
end_time-start_time
# Out:
# 0.0037183761596679688

# %%
plt.figure(figsize=(6, 6))
plt.scatter(X_resampled[:, 0], X_resampled[:, 1], s=2, c=colors[y_resampled])
plt.colorbar()
plt.show()

plt.figure(figsize=(6, 6))
plt.scatter(X_resampled2[:, 0], X_resampled2[:, 1], s=2, c=colors[y_resampled2])
plt.colorbar()
plt.show()

plt.figure(figsize=(6, 6))
plt.scatter(X_resampled3[:, 0], X_resampled3[:, 1], s=2, c=colors[y_resampled3])
plt.colorbar()
plt.show()

# %%
# stops here
